# %%
import requests
import pandas as pd
from datetime import datetime
import time

# Configuration
API_KEY = "8e90df3e35fa6be5000c72cd12951ffb"
 # Get from openweathermap.org
CITY = "Varanasi"
COUNTRY_CODE = "IN"
CSV_FILE = "livo_weather_data.csv"

def fetch_weather_data():
    """Fetch current weather and forecast data from OpenWeatherMap API"""
    
    # API endpoint for current weather
    url = f"https://api.openweathermap.org/data/2.5/weather?q={CITY},{COUNTRY_CODE}&appid={API_KEY}&units=metric"
    
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise error for bad status
        data = response.json()
        
        # Extract relevant weather information
        weather_info = {
            'Timestamp': datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
            'City': data['name'],
            'Temperature': data['main']['temp'],
            'Feels_Like': data['main']['feels_like'],
            'Humidity': data['main']['humidity'],
            'Pressure': data['main']['pressure'],
            'Weather': data['weather'][0]['main'],
            'Description': data['weather'][0]['description'],
            'Wind_Speed': data['wind']['speed'],
            'Cloudiness': data['clouds']['all']
        }
        
        return weather_info
    
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data: {e}")
        return None

def save_to_csv(weather_info, filename=CSV_FILE):
    """Save weather data to CSV file"""
    
    if weather_info is None:
        return
    
    # Convert to DataFrame
    df = pd.DataFrame([weather_info])
    
    try:
        # Check if file exists; if yes, append, if no, create new
        try:
            existing_df = pd.read_csv(filename)
            df = pd.concat([existing_df, df], ignore_index=True)
        except FileNotFoundError:
            pass  # File doesn't exist yet, just use new df
        
        df.to_csv(filename, index=False)
        print(f"Data saved to {filename}")
        print(df.tail())  # Print last few rows
    
    except Exception as e:
        print(f"Error saving to CSV: {e}")

def run_continuous_fetch(interval_minutes=60):
    """Run the fetch continuously at specified intervals"""
    
    print(f"Starting weather data fetch every {interval_minutes} minutes...")
    print(f"Press Ctrl+C to stop\n")
    
    while True:
        print(f"Fetching data at {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
        weather_info = fetch_weather_data()
        save_to_csv(weather_info)
        
        # Wait for specified interval (in seconds)
        time.sleep(interval_minutes * 60)

# Run the script
if __name__ == "__main__":
    # Option 1: Fetch once
    print("Option 1: Fetch weather data once")
    weather = fetch_weather_data()
    if weather:
        save_to_csv(weather)
    
    # Option 2: Uncomment below to run continuously every 30 minutes
    run_continuous_fetch(interval_minutes=30)
# Out:
# Option 1: Fetch weather data once
# Data saved to livo_weather_data.csv
#                Timestamp      City  Temperature  Feels_Like  Humidity  \
# 172  2025-11-01 15:22:46  Varanasi        24.97       25.61        80
# 173  2025-11-01 15:52:46  Varanasi        24.97       25.61        80
# 174  2025-11-01 16:22:47  Varanasi        24.05       24.97        94
# 175  2025-11-01 16:52:47  Varanasi        24.05       24.97        94
# 176  2025-11-01 17:18:47  Varanasi        24.05       24.97        94
#
#      Pressure  Weather              Description  Wind_Speed  Cloudiness
# 172      1009   Clouds          overcast clouds        3.69          99
# 173      1009   Clouds          overcast clouds        3.69          99
# 174      1009  Drizzle  light intensity drizzle        2.57         100
# 175      1009  Drizzle  light intensity drizzle        0.00         100
# 176      1009  Drizzle  light intensity drizzle        0.00         100
# ...

# %% [markdown]
# REQUESTS
# THIS DOSENT COME BY DEFAULT TO PYTHON (PIP INSTALL REQUESTS)
# requests is a popular third party library jo https requests bejne ke liye use hoti hai
# web se data lene ke liye,api se data fetch krne ke liye etc
# - The requests library uses urllib3 under the hood
# response = requests.get('https://api.example.com/data')
# data = response.json()  # JSON data मिलेगा
#
#
# in this code ye weather api se data fetch krne ke liye use hota hai requests.get(url)
# aur fiir errors bachne ke liye jab request me status code 200-300 hai tab theek hai lekin jab 400 aur above hai tb requests.raise_for_status()
#
# https request ka mtlb hota hai jab hmara program servers se koi data maangta hai

# %% [markdown]
# datetime python ki built in memory hai jo date aur time ke saath work krne ke liye use hoti hai
#
# ye current date,date formatting,date calculations iss sab me use hota hai
# now = datetime.now()  # Current date और time
# print(now)  # 2025-10-28 14:30:45.123456
#
# today = datetime.today()
# formatted = now.strftime('%d-%m-%Y')  # '28-10-2025'
#
# iss code me bhi ye current data ko fetch krne ke liye use horha hai
# aur taaki iski shi formatting hopayee

# %% [markdown]
# time bhi built in library hai
# ye code performance , code pause krne ke liye,timestamps ke liye
# time.sleep() ye code ko kuch time tak pause krdeta hai
#
# time.time() current time btane ke liye
#
# ye isss code me program ko hrr fixed interval ke liye sula derha hai taaki jab time aaye tbhi sirf data fetch krre

# %% [markdown]
# pandas ek python ki hi library hai jo data ko handle krne ke liye use hota hai specially tabular types data  like excell,json,csv
# pandas stands for python data analysis library
#
# iss code me ye weather data ko dataframe me convert krta hai
# aur csv files read krne ke liye
#
# purane aur new data ko combine krne ke liye ye use hota hai
# ignore_index=True ye purane index ko bhul kr naya index derha

# %% [markdown]
# iss code me procedural programming use hui hai normal function jaisa
