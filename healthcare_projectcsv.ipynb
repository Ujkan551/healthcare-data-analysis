# %% [markdown]
# # Open the CSV file by just its name

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("healthcare_dataset.csv")

# %% [markdown]
# DISPLAY FIRST FEW ROWS AND LAST FEW ROWS

# %%
data.head(5)  # Display first few rows
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
data.tail(5)  # Display last few rows
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission           Doctor                      Hospital  \
# 55495        2020-08-16    Joshua Jarvis                Jones-Thompson
# 55496        2020-01-23  Taylor Sullivan                  Tucker-Moyer
# 55497        2020-07-13   Joe Jacobs DVM  and Mahoney Johnson Vasquez,
# 55498        2019-05-25   Kimberly Curry      Jackson Todd and Castro,
# 55499        2024-04-02    Dennis Warren                Henry Sons and
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# ...

# %%
# describe the data
data.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  55500.000000    55500.000000  55500.000000
# mean      51.539459    25539.316097    301.134829
# std       19.602454    14211.454431    115.243069
# min       13.000000    -2008.492140    101.000000
# 25%       35.000000    13241.224652    202.000000
# 50%       52.000000    25538.069376    302.000000
# 75%       68.000000    37820.508436    401.000000
# max       89.000000    52764.276736    500.000000

# %%
#data type of each column
data.dtypes
# Out:
# Name                   object
# Age                     int64
# Gender                 object
# Blood Type             object
# Medical Condition      object
# Date of Admission      object
# Doctor                 object
# Hospital               object
# Insurance Provider     object
# Billing Amount        float64
# Room Number             int64
# Admission Type         object
# Discharge Date         object
# Medication             object
# Test Results           object
# dtype: object

# %%
#info about the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood Type          55500 non-null  object
#  4   Medical Condition   55500 non-null  object
#  5   Date of Admission   55500 non-null  object
#  6   Doctor              55500 non-null  object
#  7   Hospital            55500 non-null  object
#  8   Insurance Provider  55500 non-null  object
#  9   Billing Amount      55500 non-null  float64
#  10  Room Number         55500 non-null  int64
#  11  Admission Type      55500 non-null  object
#  12  Discharge Date      55500 non-null  object
#  13  Medication          55500 non-null  object
#  14  Test Results        55500 non-null  object
# ...

# %%
#How many rows and columns
data.shape
print("rows:", data.shape[0])
print("cols:", data.shape[1])
# Out:
# rows: 55500
# cols: 15

# %%
# Are there any missing values?
data.isnull().sum().head(50)
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
#check for duplicate values
data.duplicated().sum()
# Out:
# np.int64(534)

# %%
#Which columns are numerical and which are categorical?
data.select_dtypes(include='number')
data.select_dtypes(exclude='object')
data.select_dtypes(include=list(data.dtypes.unique()))
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
#What is the distribution of gender in the dataset?
k=data.value_counts("Gender") 
k
# Out:
# Gender
# Male      27774
# Female    27726
# Name: count, dtype: int64

# %%
#Now plotting Bar GRaph
k=data.value_counts("Gender") 
k.plot(kind='bar', color=['skyblue', 'orange'])

plt.title("Gender Count")
plt.xlabel("Gender")
plt.ylabel("Number of People")
plt.show()

# %%
import seaborn as sns

# Seaborn countplot

sns.countplot(data=data, x='Gender', palette=['skyblue', 'orange'])
plt.title("Gender Count")
plt.xlabel("Gender")
plt.ylabel("Number of People")
plt.show()
# Out:
# C:\Users\ujjwa\AppData\Local\Temp\ipykernel_16852\4141590725.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='Gender', palette=['skyblue', 'orange'])

# %%
k=data.value_counts("Gender") 
k.plot(kind='pie', autopct='%1.1f%%', startangle=90)

plt.title("Gender Distribution")
plt.ylabel("")  # to hide y-axis
plt.show()

# %%
#What are the top 5 most common diagnoses?
l=data['Medical Condition'].value_counts().head(5)
l
# Out:
# Medical Condition
# Arthritis       9308
# Diabetes        9304
# Hypertension    9245
# Obesity         9231
# Cancer          9227
# Name: count, dtype: int64

# %%
l=data['Medical Condition'].value_counts().head(50)
l.plot(kind='bar', color=['skyblue', 'orange', 'lightgreen', 'lightcoral', 'gold'])

plt.title("Top Diagnoses")
plt.xlabel("Condition")
plt.ylabel("Number of People")
plt.ylim(9000, 10000)  
plt.xticks(rotation=45)  # Rotate x-axis labels for clarity
plt.tight_layout()       # Avoid label cutoff
plt.show()

# %%
#The age distribution of patients
pd.set_option('display.max_rows', None)  # Show all rows in output
k= data["Age"].value_counts().sort_index()
k.head(50)
# Out:
# Age
# 13     14
# 14     18
# 15     28
# 16     24
# 17     32
# 18    772
# 19    805
# 20    750
# 21    822
# 22    817
# 23    790
# 24    837
# 25    836
# 26    815
# 27    786
# 28    760
# 29    787
# 30    806
# 31    793
# 32    755
# 33    810
# 34    864
# 35    811
# 36    799
# 37    893
# 38    897
# 39    751
# 40    752
# 41    809
# 42    821
# 43    847
# 44    836
# 45    792
# 46    830
# 47    804
# 48    803
# 49    836
# 50    831
# 51    798
# 52    817
# 53    845
# 54    842
# 55    813
# 56    856
# 57    887
# 58    852
# 59    809
# 60    778
# 61    783
# 62    816
# Name: count, dtype: int64

# %%
#How long patients each patients have stayed in the hospital?
data["Date of Admission"] = pd.to_datetime(data["Date of Admission"])
data["Discharge Date"] = pd.to_datetime(data["Discharge Date"])
data["Stay Duration"] = (data["Discharge Date"] - data["Date of Admission"])
stay_per_patient = data.groupby("Name")["Stay Duration"].sum().reset_index()
stay_per_patient.head(50)
# Out:
#                  Name Stay Duration
# 0        AARON DuncAn       11 days
# 1         AARON HicKS       13 days
# 2   AARON bAldWIN Jr.       26 days
# 3       AARON hAWkIns        9 days
# 4          AAROn HaRt        7 days
# 5        AAROn wiLsON       22 days
# 6        AARoN FOSTer        9 days
# 7       AARoN HOPkINs        4 days
# 8        AARoN grEEnE        9 days
# 9         AARon OnEal        4 days
# 10        AARon SmIth       30 days
# 11      AARon goOdwIn       26 days
# 12         AARon poPe       26 days
# 13        AARon smITh       58 days
# 14      AArON BeNtlEy       13 days
# 15      AArON GOoDmAN       18 days
# 16    AArON ROdRIgueZ        1 days
# 17   AArON RiChaRDsON       21 days
# 18       AArON rOmEro       16 days
# 19   AArON sTrICkLanD       12 days
# 20     AArOn AnderSoN       28 days
# 21         AArOn CoOK       30 days
# 22        AArOn DaVIs        8 days
# 23      AArOn STAnLey        8 days
# 24         AArOn huFf       13 days
# ...

# %%
#Most common blood group
l=data['Blood Type'].value_counts().head(15)
l.plot(kind='bar', color=['skyblue', 'orange', 'lightgreen', 'lightcoral', 'gold'])

plt.title("Top Blood Groups")
plt.xlabel("Blood Type")
plt.ylabel("number of People")
plt.ylim(6900, 7000)  
plt.xticks(rotation=60)  # Rotate x-axis labels for clarity
plt.show()

# %%
#The admission was 
data.groupby("Name")["Admission Type"].sum().head(50)
# Out:
# Name
# AARON DuncAn                     Urgent
# AARON HicKS                    Elective
# AARON bAldWIN Jr.                Urgent
# AARON hAWkIns                    Urgent
# AAROn HaRt                    Emergency
# AAROn wiLsON                  Emergency
# AARoN FOSTer                     Urgent
# AARoN HOPkINs                 Emergency
# AARoN grEEnE                  Emergency
# AARon OnEal                   Emergency
# AARon SmIth                    Elective
# AARon goOdwIn                 Emergency
# AARon poPe                     Elective
# AARon smITh          EmergencyEmergency
# AArON BeNtlEy                 Emergency
# AArON GOoDmAN                 Emergency
# AArON ROdRIgueZ                Elective
# AArON RiChaRDsON               Elective
# AArON rOmEro                     Urgent
# AArON sTrICkLanD              Emergency
# AArOn AnderSoN                   Urgent
# AArOn CoOK                     Elective
# AArOn DaVIs                    Elective
# ...

# %% [markdown]
# WHAT IS THE AVG AGE PER GENDER

# %%
data.groupby("Gender")["Age"].mean()
# Out:
# Gender
# Female    51.578735
# Male      51.500252
# Name: Age, dtype: float64

# %%
#now bar plot for this
k=data.groupby("Gender")["Age"].mean()
k.plot(kind='bar', color=['skyblue', 'orange'])
plt.title("Average Age per gender")
plt.xlabel("Gender")
plt.ylim(51,52)
plt.ylabel("Average Age")
plt.show()

# %% [markdown]
# How many patients are below 18, 18–40, 41–60, 60+?

# %%
def patient_age(Age):
    if Age < 18:
        return "Child"
    elif 18 <= Age < 60:
        return "Adult"
    else:
        return "Senior"
data["Age Group"] = data["Age"].apply(patient_age)

data[["Age", "Age Group"]].head(50)
# Out:
#     Age Age Group
# 0    30     Adult
# 1    62    Senior
# 2    76    Senior
# 3    28     Adult
# 4    43     Adult
# 5    36     Adult
# 6    21     Adult
# 7    20     Adult
# 8    82    Senior
# 9    58     Adult
# 10   72    Senior
# 11   38     Adult
# 12   75    Senior
# 13   68    Senior
# 14   44     Adult
# 15   46     Adult
# 16   63    Senior
# 17   38     Adult
# 18   34     Adult
# 19   63    Senior
# 20   67    Senior
# 21   48     Adult
# 22   58     Adult
# 23   59     Adult
# 24   72    Senior
# 25   73    Senior
# 26   51     Adult
# 27   34     Adult
# 28   38     Adult
# 29   63    Senior
# 30   34     Adult
# 31   23     Adult
# 32   78    Senior
# 33   43     Adult
# 34   30     Adult
# 35   25     Adult
# 36   33     Adult
# 37   26     Adult
# 38   70    Senior
# 39   57     Adult
# 40   74    Senior
# 41   81    Senior
# 42   49     Adult
# 43   26     Adult
# 44   81    Senior
# 45   65    Senior
# 46   31     Adult
# 47   58     Adult
# 48   22     Adult
# ...

# %%
data["Age Group"].value_counts().plot(kind='bar', color=['skyblue', 'orange', 'lightgreen'])
plt.title("Age Group Distribution")
plt.xlabel("Age Group")
plt.ylabel("Number of People")
plt.show()

# %% [markdown]
# WHICH HOSPITAL TREATS THE MOST PATIENTS

# %%
data.head(5)
data.groupby("Hospital")["Name"].count().sort_values(ascending=False).head(50)
# Out:
# Hospital
# LLC Smith         44
# Ltd Smith         39
# Johnson PLC       38
# Smith Ltd         37
# Smith Group       36
# Smith PLC         36
# Johnson Inc       35
# Smith Inc         34
# Group Smith       32
# Smith LLC         32
# LLC Johnson       30
# PLC Williams      30
# PLC Smith         29
# Brown Inc         28
# Inc Brown         28
# Johnson Group     27
# Inc Smith         27
# Inc Johnson       26
# Group Johnson     26
# Williams LLC      25
# Inc Jones         25
# Brown LLC         24
# Inc Williams      23
# Johnson LLC       23
# Jones Group       23
# LLC Williams      23
# Johnson Ltd       22
# Brown Group       22
# Miller Inc        22
# Jones Ltd         22
# Brown PLC         22
# Williams Group    22
# Jones LLC         22
# Group Brown       22
# Ltd Johnson       21
# Ltd Brown         21
# Inc Jackson       20
# Williams PLC      20
# Group Davis       20
# Inc Rodriguez     19
# Brown Ltd         19
# Group Jones       19
# Williams Inc      19
# ...
